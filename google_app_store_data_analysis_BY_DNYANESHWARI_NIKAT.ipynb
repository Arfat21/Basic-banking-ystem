# %% [markdown]
# <a href="https://colab.research.google.com/github/Arfat21/Basic-banking-ystem/blob/main/google_app_store_data_analysis_BY_DNYANESHWARI_NIKAT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns #visualisation
import matplotlib.pyplot as plt #visualisation
# %matplotlib inline 
sns.set(color_codes=True)

# %%
df = pd.read_csv('/content/Google Apps data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  \
# 0           0             0
# 1           1             1
# 2           2             5
# 3           3             6
# 4           4             7
#
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  Art And Design     4.1
# 1                                Coloring book moana  Art And Design     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  Art And Design     4.7
# 3                              Sketch - Draw & Paint  Art And Design     4.5
# 4              Pixel Draw - Number Art Coloring Book  Art And Design     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating      Last Updated  \
# 0      159  19.0     10000  Free    0.0         Others   January 7, 2018
# 1      967  14.0    500000  Free    0.0         Others  January 15, 2018
# 2    87510   8.7   5000000  Free    0.0         Others    August 1, 2018
# ...

# %% [markdown]
# DATA CLEANNG

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8276 entries, 0 to 8275
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           8276 non-null   int64
#  1   Unnamed: 0.1         8276 non-null   int64
#  2   App                  8276 non-null   object
#  3   Category             8276 non-null   object
#  4   Rating               8276 non-null   float64
#  5   Reviews              8276 non-null   int64
#  6   Size                 8276 non-null   float64
#  7   Installs             8276 non-null   int64
#  8   Type                 8276 non-null   object
#  9   Price                8276 non-null   float64
#  10  Content Rating       7915 non-null   object
#  11  Last Updated         8276 non-null   object
#  12  Current Ver          8276 non-null   object
#  13  Minimum Android Ver  8276 non-null   object
#  14  Genres               8276 non-null   object
# ...

# %%
df.drop_duplicates()
# Out:
#       Unnamed: 0  Unnamed: 0.1  \
# 0              0             0
# 1              1             1
# 2              2             5
# 3              3             6
# 4              4             7
# ...          ...           ...
# 8271        8271          8912
# 8272        8272          8913
# 8273        8273          8914
# 8274        8274          8915
# 8275        8275          8916
#
#                                                     App             Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook       Art And Design
# 1                                   Coloring book moana       Art And Design
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...       Art And Design
# 3                                 Sketch - Draw & Paint       Art And Design
# 4                 Pixel Draw - Number Art Coloring Book       Art And Design
# ...                                                 ...                  ...
# ...

# %%
df.count()
# Out:
# Unnamed: 0             8276
# Unnamed: 0.1           8276
# App                    8276
# Category               8276
# Rating                 8276
# Reviews                8276
# Size                   8276
# Installs               8276
# Type                   8276
# Price                  8276
# Content Rating         7915
# Last Updated           8276
# Current Ver            8276
# Minimum Android Ver    8276
# Genres                 8276
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Unnamed: 0               0
# Unnamed: 0.1             0
# App                      0
# Category                 0
# Rating                   0
# Reviews                  0
# Size                     0
# Installs                 0
# Type                     0
# Price                    0
# Content Rating         361
# Last Updated             0
# Current Ver              0
# Minimum Android Ver      0
# Genres                   0
# dtype: int64

# %%
df.dropna()
# Out:
#       Unnamed: 0  Unnamed: 0.1  \
# 0              0             0
# 1              1             1
# 2              2             5
# 3              3             6
# 4              4             7
# ...          ...           ...
# 8270        8270          8911
# 8271        8271          8912
# 8272        8272          8913
# 8273        8273          8914
# 8275        8275          8916
#
#                                                     App             Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook       Art And Design
# 1                                   Coloring book moana       Art And Design
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...       Art And Design
# 3                                 Sketch - Draw & Paint       Art And Design
# 4                 Pixel Draw - Number Art Coloring Book       Art And Design
# ...                                                 ...                  ...
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0  Unnamed: 0.1       Rating       Reviews         Size  \
# count  8276.000000   8276.000000  8276.000000  8.276000e+03  8276.000000
# mean   4137.500000   4560.609957     4.175121  2.803270e+05    18.897761
# std    2389.219747   2560.879748     0.534762  2.096170e+06    22.376521
# min       0.000000      0.000000     1.000000  1.000000e+00     0.008300
# 25%    2068.750000   2459.750000     4.000000  1.290000e+02     2.800000
# 50%    4137.500000   4613.500000     4.300000  3.213500e+03     9.500000
# 75%    6206.250000   6765.250000     4.500000  4.627800e+04    27.000000
# max    8275.000000   8916.000000     5.000000  7.815831e+07   100.000000
#
#            Installs        Price
# count  8.276000e+03  8276.000000
# mean   9.658206e+06     1.028758
# std    5.986505e+07    16.776622
# min    1.000000e+00     0.000000
# 25%    1.000000e+04     0.000000
# 50%    1.000000e+05     0.000000
# 75%    1.000000e+06     0.000000
# max    1.000000e+09   400.000000

# %%
df.boxplot()

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f945dfc5a30>,
# ...
#       dtype=object)

# %% [markdown]
# DATA MANIPULATION

# %%
df[df.Rating>10]
# Out:
#       Unnamed: 0  Unnamed: 0.1  \
# 0              0             0
# 2              2             5
# 3              3             6
# 4              4             7
# 5              5             9
# ...          ...           ...
# 8270        8270          8911
# 8272        8272          8913
# 8273        8273          8914
# 8274        8274          8915
# 8275        8275          8916
#
#                                                     App             Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook       Art And Design
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...       Art And Design
# 3                                 Sketch - Draw & Paint       Art And Design
# 4                 Pixel Draw - Number Art Coloring Book       Art And Design
# 5                            Paper flowers instructions       Art And Design
# ...                                                 ...                  ...
# ...

# %% [markdown]
# lets took a look on all category

# %%
cat = df.Category.unique()    
cat
# Out:
# array(['Art And Design', 'Auto And Vehicles', 'Beauty',
#        'Books And Reference', 'Business', 'Comics', 'Communication',
#        'Dating', 'Education', 'Entertainment', 'Events', 'Finance',
#        'Food And Drink', 'Health And Fitness', 'House And Home',
#        'Libraries And Demo', 'Lifestyle', 'Game', 'Family', 'Medical',
#        'Social', 'Shopping', 'Photography', 'Sports', 'Travel And Local',
#        'Tools', 'Personalization', 'Productivity', 'Parenting', 'Weather',
#        'Video Players', 'News And Magazines', 'Maps And Navigation'],
#       dtype=object)

# %% [markdown]
# there are 34 categories solets see which is fmaous category

# %%
plt.figure(figsize=(15,10)) 
most_cat = df.Category.value_counts()
sns.barplot(x = most_cat, y = most_cat.index, data=df)

# %% [markdown]
# so here around 2000 app with family category and game category with 1200 it mean family category is the famous category

# %%
g = sns.FacetGrid(df, col='Category', palatte = "Set1", col_wrap=5, height=4)
g = (g.map(sns.displot, "Rating", hist= False, rug=True, color = "g"))

# %%
plt.figure(figsize=(12,8))
sns.barplot(x='Price',y='Transmission',hue='Drive Mode',data=df)

# %%
plt.figure(figsize=(12,12))
most_cat = df.Category.value_counts()
sns.barplot(x=most_cat, y=most_cat.index, data=df)

# %% [markdown]
# letts see the rating and what kind of correlation they share with each other

# %%
df.Rating.unique()
# Out:
# array([4.1, 3.9, 4.7, 4.5, 4.3, 4.4, 3.8, 4.2, 4.6, 4. , 4.8, 4.9, 3.6,
#        3.7, 3.2, 3.3, 3.4, 3.5, 3.1, 5. , 2.6, 3. , 1.9, 2.5, 2.8, 2.7,
#        1. , 2.9, 2.3, 2.2, 1.7, 2. , 1.8, 2.4, 1.6, 2.1, 1.4, 1.5, 1.2])

# %%
df['Rating'].replace(to_replace=[19.0], value=[1.9],inplace=True)
sns.distplot(df.Rating)

# %% [markdown]
# Most of the rating is around 4. Let’s see how rating is distributed by category column.

# %%
g = sns.FacetGrid(df, col='Category', palette="Set1",  col_wrap=5, height=4)
g = (g.map(sns.distplot, "Rating", hist=False, rug=True, color="r"))

# %% [markdown]
# By the horizontal is the rating value, and vertically is quantity of the rating

# %%
# Mean Rating
plt.figure(figsize=(12,12))
mean_rat = df.groupby(['Category'])['Rating'].mean().sort_values(ascending=False)
sns.barplot(x=mean_rat, y=mean_rat.index, data=df)

# %% [markdown]
# And this is the average of rating by category, family and game has a lot of quantity causing the low on average rating, on the other side event has the highest average rating by category.
#
# Next is reviews, review sometime can measure the app popularity. The more reviews, the better.

# %%
# Reviews
df.Reviews.unique()
# Out:
# array([   159,    967,  87510, ...,    603,   1195, 398307])

# %%
# inside review there is a value with 3.0M with M stand for million, lets change it so it can be measure as float

Reviews = []

for x in df.Reviews:
    x = x.replace('M','00')
    Reviews.append(x)

Reviews = list(map(float, Reviews))
df['reviews'] = Reviews
sns.distplot(Reviews)

# %%
g = sns.FacetGrid(df, col='Category', palette="Set1",  col_wrap=5, height=4)
g = (g.map(plt.hist, "Reviews", color="g"))

# %%
# Total reviews
plt.figure(figsize=(12,12))
sum_rew = df.groupby(['Category'])['Reviews'].sum().sort_values(ascending=False)
sns.barplot(x=sum_rew, y=sum_rew.index, data=df)

# %% [markdown]
# showingn the total amount of total review

# %%
plt.figure(figsize=(12,12))
mean_rew = df.groupby(['Category'])['Reviews'].mean().sort_values(ascending=False)
sns.barplot(x=mean_rew, y=mean_rew.index, data=df)

# %% [markdown]
# this is the average of reviews on each category lrts see the column ' Installs'

# %%
# Installs
df.Installs.unique()
# Out:
# array([     10000,     500000,    5000000,   50000000,     100000,
#             50000,    1000000,   10000000,       5000,  100000000,
#        1000000000,       1000,  500000000,        100,        500,
#                10,          5,         50,          1])

# %%
df['Installs'].replace(to_replace=['0', 'Free'], value=['0+','0+'],inplace=True)
Installs = []

for x in df.Installs:
    x = x.replace(',', '')
    Installs.append(x[:-1])

Installs = list(map(float, Installs))
df['installs'] = Installs
sns.distplot(Installs)

# %% [markdown]
# distributed value of Installs on each category

# %%
g = sns.FacetGrid(df, col='Category', palette="Set1",  col_wrap=5, height=4)
g = (g.map(plt.hist, "Installs", bins=5, color='c'))

# %%
# Total Installs
plt.figure(figsize=(12,12))
sum_inst = df.groupby(['Category'])['Installs'].sum().sort_values(ascending=False)
sns.barplot(x=sum_inst, y=sum_inst.index, data=df)

# %% [markdown]
# the type column , lets check the app is paid or free

# %%
 #Type for category
df.Type.unique()
# Out:
# array(['Free', 'Paid'], dtype=object)

# %%
print(df.groupby('Category')['Type'].value_counts())
Type_cat = df.groupby('Category')['Type'].value_counts().unstack().plot.barh(figsize=(10,20), width=0.7)
plt.show()
# Out:
# Category           Type
# Art And Design     Free     57
#                    Paid      3
# Auto And Vehicles  Free     72
#                    Paid      1
# Beauty             Free     42
#                           ...
# Travel And Local   Paid      8
# Video Players      Free    146
#                    Paid      4
# Weather            Free     65
#                    Paid      7
# Name: Type, Length: 61, dtype: int64

# %% [markdown]
# So again, family category has the most free and paid app on the google play store. We can see social app is always free, like entertainment, event, education, comic, and more.
#
# The medical has a high amount of paid app considering quantity of medical app is not much.

# %%
#Lets is the version of android you should have before accessing the app.


# Android Version

df['Minimum Android Ver'].unique()
# Out:
# array(['4.0.3', '4.2', '4.4', '2.3', '3.0', '4.1', '4.0', '2.3.3', '-1',
#        '2.2', '5.0', '6.0', '1.6', '1.5', '2.1', '7.0', '4.3', '2.0',
#        '3.2', '5.1', '7.1', '8.0', '3.1', '2.0.1', '1.0'], dtype=object)

# %%
#Now I am going to group it to 1 till 8 version of android. Change the null value to 1.0.

1
df['Minimum Android Ver'].replace(to_replace=['4.4W and up','Varies with device'], value=['4.4','1.0'],inplace=True)
2
df['Minimum Android Ver'].replace({k: '1.0' for k in ['1.0','1.0 and up','1.5 and up','1.6 and up']},inplace=True)
3
df['Minimum Android Ver'].replace({k: '2.0' for k in ['2.0 and up','2.0.1 and up','2.1 and up','2.2 and up','2.2 - 7.1.1','2.3 and up','2.3.3 and up']},inplace=True)
4
df['Minimum Android Ver'].replace({k: '3.0' for k in ['3.0 and up','3.1 and up','3.2 and up']},inplace=True)
5
df['Minimum Android Ver'].replace({k: '4.0' for k in ['4.0 and up','4.0.3 and up','4.0.3 - 7.1.1','4.1 and up','4.1 - 7.1.1','4.2 and up','4.3 and up','4.4','4.4 and up']},inplace=True)
6
df['Minimum Android Ver'].replace({k: '5.0' for k in ['5.0 - 6.0','5.0 - 7.1.1','5.0 - 8.0','5.0 and up','5.1 and up']},inplace=True)
7
df['Minimum Android Ver'].replace({k: '6.0' for k in ['6.0 and up']},inplace=True)
8
df['Minimum Android Ver'].replace({k: '7.0' for k in ['7.0 - 7.1.1','7.0 and up','7.1 and up']},inplace=True)
9
df['Minimum Android Ver'].replace({k: '8.0' for k in ['8.0 and up']},inplace=True)
10
df['Minimum Android Ver'].fillna('1.0', inplace=True)

# %%
print(df.groupby('Category')['Minimum Android Ver'].value_counts())
Type_cat = df.groupby('Category')['Minimum Android Ver'].value_counts().unstack().plot.barh(figsize=(15,20), width=3)
plt.show()
# Out:
# Category        Minimum Android Ver
# Art And Design  4.1                    20
#                 4.0.3                  16
#                 4.0                    10
#                 2.3                     7
#                 3.0                     2
#                                        ..
# Weather         2.2                     2
#                 4.2                     2
#                 1.6                     1
#                 2.3.3                   1
#                 3.0                     1
# Name: Minimum Android Ver, Length: 459, dtype: int64

# %% [markdown]
# This dataset contains a good set of possibilities, to work more on the business values and leaving with a positive impact. This work is not restricted to until the exploration of this article. You can explore more interesting facts and figures using this article.
